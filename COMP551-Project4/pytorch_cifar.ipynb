# %%
# Mounting Google Drive locally
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Navigate to folder containing project
import os
os.chdir("drive/My Drive/COMP 551 Project 4/")

# %%
# !git clone --recursive https://github.com/bearpaw/pytorch-classification.git
# Out:
# Cloning into 'pytorch-classification'...
# remote: Enumerating objects: 287, done.
# remote: Total 287 (delta 0), reused 0 (delta 0), pack-reused 287
# Receiving objects: 100% (287/287), 440.37 KiB | 633.00 KiB/s, done.
# Resolving deltas: 100% (167/167), done.
# Submodule 'utils/progress' (https://github.com/verigak/progress.git) registered for path 'utils/progress'
# Cloning into '/content/drive/My Drive/COMP 551 Project 4/pytorch-classification/pytorch-classification/utils/progress'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 250 (delta 0), reused 0 (delta 0), pack-reused 249
# Receiving objects: 100% (250/250), 648.92 KiB | 904.00 KiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Submodule path 'utils/progress': checked out '715a2e130f14fa95c092c771813fb1c729dae333'

# %%
os.chdir("pytorch-classification")

# %%
# !ls
# Out:
# cifar.py     LICENSE  pytorch-classification  TRAINING.md
# imagenet.py  models   README.md		      utils

# %% [markdown]
# #CIFAR 10

# %%
# !python cifar.py -a resnet --depth 110 --epochs 164 --schedule 81 122 --gamma 0.1 --wd 1e-4 --checkpoint checkpoints/cifar10/resnet-110
# Out:
# Traceback (most recent call last):
#   File "cifar.py", line 23, in <module>
#     from utils import Bar, Logger, AverageMeter, accuracy, mkdir_p, savefig
#   File "/content/drive/My Drive/COMP 551 Project 4/pytorch-classification/utils/__init__.py", line 11, in <module>
#     from progress.bar import Bar as Bar
# ModuleNotFoundError: No module named 'progress'

# %%
python cifar.py -a vgg19_bn --epochs 164 --schedule 81 122 --gamma 0.1 --checkpoint checkpoints/cifar10/vgg19_bn

# %% [markdown]
# #CIFAR 100

# %%
python cifar.py -a vgg19_bn --dataset cifar100 --checkpoint checkpoints/cifar100/vgg19_bn --epochs 164 --schedule 81 122 --gamma 0.1

# %%
python cifar.py -a resnet --dataset cifar100 --depth 110 --epochs 164 --schedule 81 122 --gamma 0.1 --wd 1e-4 --checkpoint checkpoints/cifar100/resnet-110
